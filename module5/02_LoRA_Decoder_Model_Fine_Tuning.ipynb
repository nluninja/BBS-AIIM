# %% [markdown]
# <a href="https://colab.research.google.com/github/nluninja/BBS-AIIM/blob/main/module5/02_LoRA_Decoder_Model_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LoRA Fine-Tuning for Decoder Models: GPT-2 Text Generation
#
# This notebook demonstrates LoRA (Low-Rank Adaptation) fine-tuning on a decoder-only transformer model (GPT-2) for text generation tasks. We'll explore:
#
# 1. **Decoder Model Setup**: Loading and configuring GPT-2
# 2. **LoRA for Generation**: Adapting LoRA for causal language modeling
# 3. **Dataset Preparation**: Preparing text data for generation tasks
# 4. **Training Process**: Fine-tuning with generation-specific metrics
# 5. **Generation Evaluation**: Assessing text quality and coherence
# 6. **Comparative Analysis**: Before/after generation samples
#
# ## Decoder Models vs Encoder Models
#
# Key differences when working with decoder models:
# - **Autoregressive generation**: Models predict next tokens sequentially
# - **Causal attention**: Only attend to previous tokens
# - **Generation metrics**: Perplexity, BLEU, coherence measures
# - **Different LoRA targets**: Focus on attention and MLP layers
#
# ## Use Case: Creative Writing Assistant
#
# We'll fine-tune GPT-2 to become a specialized creative writing assistant, demonstrating how LoRA can adapt a general language model for specific generation tasks.

# %%
# Install required packages for decoder model fine-tuning
# !pip install transformers datasets peft torch accelerate evaluate matplotlib seaborn pandas numpy tqdm nltk rouge-score sacrebleu
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.11.0+cu128)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.29.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.16.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (6.1.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.5.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.2 MB/s eta 0:00:00
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 4.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=9856de2ee55e7a6a06699ad850e0658f8b96564aac7b0dcbff7896c4176a8685
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# Installing collected packages: portalocker, colorama, sacrebleu, rouge-score, evaluate
# Successfully installed colorama-0.4.6 evaluate-0.4.6 portalocker-3.2.0 rouge-score-0.1.2 sacrebleu-2.6.0

# %%
import torch
import torch.nn as nn
from transformers import (
    AutoTokenizer,
    GPT2LMHeadModel,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling,
    pipeline
)
from peft import LoraConfig, get_peft_model, TaskType
from datasets import load_dataset, Dataset
import evaluate
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import json
import time
import warnings
import nltk
from nltk.translate.bleu_score import sentence_bleu
import re
warnings.filterwarnings('ignore')

# Download NLTK data
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Device setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Using device: cuda
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## 1. Decoder Model Setup
#
# We'll use GPT-2 medium as our base model, which provides a good balance between capability and computational requirements.

# %%
# Model configuration
MODEL_NAME = "gpt2-medium"  # ~355M parameters
MAX_LENGTH = 512

# Load tokenizer and model
print("Loading GPT-2 tokenizer and model...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = GPT2LMHeadModel.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
)

# Add padding token (GPT-2 doesn't have one by default)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    model.config.pad_token_id = model.config.eos_token_id

print(f"Model loaded: {MODEL_NAME}")
print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Vocabulary size: {tokenizer.vocab_size:,}")
print(f"Max position embeddings: {model.config.max_position_embeddings}")
print(f"Number of layers: {model.config.num_hidden_layers}")
print(f"Hidden size: {model.config.hidden_size}")
# Out:
# Loading GPT-2 tokenizer and model...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2-medium
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...23}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Model loaded: gpt2-medium
# Total parameters: 354,823,168
# Vocabulary size: 50,257
# Max position embeddings: 1024
# Number of layers: 24
# Hidden size: 1024

# %% [markdown]
# ## 2. Dataset Preparation for Text Generation
#
# We'll use a creative writing dataset to fine-tune our model for story generation.

# %%
# Create a creative writing dataset
# For demonstration, we'll use a subset of writing prompts and stories
creative_writing_data = [
    "The old lighthouse keeper had a secret that he'd never told anyone. Every night at midnight, the lighthouse would emit a different colored light, and strange things would happen in the town below.",
    "In a world where colors could be harvested from emotions, Sarah discovered she was the only person who could see the true spectrum of human feelings.",
    "The last bookstore on Earth was hidden in a subway tunnel, and its owner claimed that every book contained a portal to another dimension.",
    "When the clocks stopped working worldwide, time became a currency that could be traded, saved, or stolen.",
    "The forest whispered secrets to those who knew how to listen, but Maya was the first person in centuries to understand what it was really trying to say.",
    "Every mirror in the old mansion showed a different time period, and Elena realized she could step through them to change history.",
    "The city's streetlights weren't powered by electricity, but by the dreams of its sleeping residents.",
    "In the floating city above the clouds, gravity worked differently for everyone, depending on their deepest fears.",
    "The music box played a melody that could heal any wound, but it demanded a memory in return for each note.",
    "When words started disappearing from books around the world, a young librarian discovered they were being stolen by someone trying to rewrite reality."
]

# Expand the dataset by adding continuation prompts
expanded_data = []
for story in creative_writing_data:
    # Original story
    expanded_data.append(story)

    # Add variations and continuations
    sentences = story.split('. ')
    if len(sentences) > 1:
        # First sentence as prompt
        expanded_data.append(sentences[0] + '.')
        # First two sentences
        if len(sentences) > 2:
            expanded_data.append('. '.join(sentences[:2]) + '.')

# Create dataset
dataset_dict = {'text': expanded_data * 10}  # Repeat for more training data
dataset = Dataset.from_dict(dataset_dict)
dataset = dataset.train_test_split(test_size=0.2, seed=42)

print(f"Training samples: {len(dataset['train'])}")
print(f"Validation samples: {len(dataset['test'])}")

# Preview dataset
print("\nSample texts:")
for i in range(3):
    print(f"{i+1}. {dataset['train'][i]['text'][:100]}...\n")
# Out:
# Training samples: 88
# Validation samples: 22
#
# Sample texts:
# 1. In the floating city above the clouds, gravity worked differently for everyone, depending on their d...
#
# 2. The last bookstore on Earth was hidden in a subway tunnel, and its owner claimed that every book con...
#
# 3. When words started disappearing from books around the world, a young librarian discovered they were ...

# %%
# Tokenization function for causal language modeling
def tokenize_function(examples):
    # Tokenize and add special tokens
    tokenized = tokenizer(
        examples['text'],
        truncation=True,
        padding=False,
        max_length=MAX_LENGTH,
        return_overflowing_tokens=False,
    )
    return tokenized

# Tokenize datasets
print("Tokenizing datasets...")
tokenized_datasets = dataset.map(tokenize_function, batched=True, remove_columns=['text'])
print("Tokenization complete!")

# Data collator for language modeling (handles padding and labels)
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,  # We're doing causal LM, not masked LM
    pad_to_multiple_of=8 if torch.cuda.is_available() else None,
)

print(f"Sample tokenized length: {len(tokenized_datasets['train'][0]['input_ids'])}")
# Out:
# Tokenizing datasets...
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# Map:   0%|          | 0/22 [00:00<?, ? examples/s]
# Tokenization complete!
# Sample tokenized length: 20

# %% [markdown]
# ## 3. LoRA Configuration for Decoder Models
#
# For decoder models, we typically target different modules compared to encoder models. We'll focus on attention and MLP layers.

# %%
# Examine model architecture to identify target modules
print("Model architecture overview:")
print("Available modules for LoRA targeting:")

for name, module in model.named_modules():
    if isinstance(module, (nn.Linear, nn.Conv1d)):
        if any(target in name for target in ['attn', 'mlp']):
            print(f"  {name}: {type(module).__name__} - Shape: {module.weight.shape}")

print("\nTypical LoRA targets for GPT-2:")
print("- c_attn: Combined query, key, value projections")
print("- c_proj: Attention output projection")
print("- c_fc: MLP feed-forward layer")
print("- c_proj (MLP): MLP output projection")
# Out:
# Model architecture overview:
# Available modules for LoRA targeting:
#
# Typical LoRA targets for GPT-2:
# - c_attn: Combined query, key, value projections
# - c_proj: Attention output projection
# - c_fc: MLP feed-forward layer
# - c_proj (MLP): MLP output projection

# %%
# LoRA configuration for decoder model
lora_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,  # Causal language modeling
    r=32,  # Slightly higher rank for generation tasks
    lora_alpha=64,  # Higher alpha for more adaptation strength
    lora_dropout=0.05,  # Lower dropout for generation
    target_modules=[
        "c_attn",    # Attention projections (Q, K, V combined)
        "c_proj",    # Attention output projection
        "c_fc",      # MLP feed-forward
    ],
    bias="none",
    inference_mode=False,
)

print("LoRA Configuration for GPT-2:")
print(f"Task type: {lora_config.task_type}")
print(f"Rank (r): {lora_config.r}")
print(f"Alpha: {lora_config.lora_alpha}")
print(f"Dropout: {lora_config.lora_dropout}")
print(f"Target modules: {lora_config.target_modules}")
print(f"Effective scaling: {lora_config.lora_alpha / lora_config.r}")
# Out:
# LoRA Configuration for GPT-2:
# Task type: TaskType.CAUSAL_LM
# Rank (r): 32
# Alpha: 64
# Dropout: 0.05
# Target modules: {'c_fc', 'c_proj', 'c_attn'}
# Effective scaling: 2.0

# %%
pip install --upgrade torchao>=0.16.0

# %%
# Apply LoRA to the model
print("Applying LoRA to GPT-2...")
lora_model = get_peft_model(model, lora_config)

# Print trainable parameters
def print_trainable_parameters(model):
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"Trainable params: {trainable_params:,} || "
        f"All params: {all_param:,} || "
        f"Trainable%: {100 * trainable_params / all_param:.4f}%"
    )

print("\nParameter comparison:")
print_trainable_parameters(lora_model)

# Show LoRA modules added
print("\nLoRA modules added:")
for name, module in lora_model.named_modules():
    if 'lora' in name.lower():
        print(f"  {name}: {type(module).__name__}")

# Move model to device
lora_model.to(device)
print(f"\nModel moved to {device}")
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Applying LoRA to GPT-2...
#
# Parameter comparison:
# Trainable params: 12,582,912 || All params: 367,406,080 || Trainable%: 3.4248%
#
# LoRA modules added:
#   base_model.model.transformer.h.0.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.0.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.0.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.0.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.0.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.0.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.0.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.0.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.0.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.0.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.0.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.0.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.0.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.0.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.0.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.0.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.0.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.0.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.0.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.0.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.0.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.1.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.1.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.1.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.1.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.1.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.1.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.1.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.1.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.1.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.1.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.1.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.1.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.1.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.1.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.1.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.1.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.2.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.2.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.2.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.2.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.2.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.2.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.2.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.2.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.2.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.2.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.2.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.2.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.2.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.2.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.2.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.2.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.3.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.3.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.3.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.3.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.3.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.3.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.3.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.3.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.3.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.3.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.3.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.3.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.3.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.3.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.3.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.3.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.4.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.4.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.4.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.4.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.4.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.4.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.4.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.4.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.4.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.4.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.4.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.4.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.4.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.4.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.4.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.4.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.5.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.5.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.5.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.5.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.5.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.5.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.5.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.5.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.5.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.5.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.5.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.5.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.5.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.5.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.5.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.5.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.6.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.6.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.6.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.6.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.6.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.6.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.6.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.6.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.6.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.6.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.6.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.6.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.6.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.6.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.6.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.6.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.7.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.7.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.7.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.7.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.7.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.7.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.7.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.7.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.7.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.7.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.7.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.7.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.7.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.7.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.7.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.7.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.8.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.8.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.8.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.8.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.8.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.8.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.8.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.8.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.8.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.8.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.8.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.8.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.8.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.8.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.8.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.8.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.9.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.9.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.9.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.9.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.9.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.9.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.9.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.9.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.9.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.9.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.9.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.9.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.9.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.9.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.9.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.9.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.10.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.10.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.10.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.10.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.10.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.10.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.10.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.10.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.10.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.10.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.10.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.10.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.10.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.10.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.10.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.10.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.11.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.11.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.11.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.11.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.11.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.11.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.11.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.11.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.11.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.11.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.11.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.11.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.11.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.11.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.11.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.11.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.12.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.12.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.12.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.12.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.12.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.12.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.12.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.12.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.12.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.12.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.12.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.12.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.12.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.12.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.12.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.12.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.13.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.13.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.13.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.13.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.13.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.13.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.13.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.13.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.13.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.13.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.13.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.13.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.13.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.13.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.13.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.13.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.14.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.14.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.14.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.14.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.14.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.14.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.14.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.14.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.14.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.14.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.14.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.14.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.14.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.14.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.14.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.14.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.15.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.15.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.15.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.15.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.15.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.15.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.15.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.15.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.15.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.15.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.15.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.15.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.15.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.15.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.15.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.15.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.16.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.16.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.16.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.16.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.16.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.16.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.16.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.16.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.16.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.16.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.16.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.16.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.16.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.16.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.16.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.16.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.17.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.17.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.17.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.17.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.17.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.17.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.17.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.17.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.17.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.17.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.17.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.17.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.17.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.17.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.17.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.17.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.18.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.18.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.18.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.18.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.18.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.18.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.18.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.18.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.18.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.18.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.18.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.18.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.18.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.18.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.18.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.18.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.19.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.19.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.19.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.19.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.19.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.19.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.19.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.19.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.19.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.19.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.19.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.19.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.19.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.19.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.19.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.19.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.20.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.20.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.20.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.20.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.20.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.20.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.20.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.20.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.20.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.20.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.20.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.20.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.20.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.20.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.20.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.20.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.21.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.21.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.21.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.21.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.21.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.21.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.21.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.21.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.21.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.21.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.21.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.21.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.21.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.21.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.21.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.21.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.22.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.22.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.22.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.22.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.22.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.22.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.22.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.22.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.22.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.22.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.22.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.22.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.22.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.22.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.22.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.22.mlp.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_dropout: ModuleDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_dropout.default: Dropout
#   base_model.model.transformer.h.23.attn.c_attn.lora_A: ModuleDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_A.default: Linear
#   base_model.model.transformer.h.23.attn.c_attn.lora_B: ModuleDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_B.default: Linear
#   base_model.model.transformer.h.23.attn.c_attn.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.23.attn.c_attn.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.23.attn.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.23.attn.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.23.attn.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.23.attn.c_proj.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_dropout: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_dropout.default: Dropout
#   base_model.model.transformer.h.23.mlp.c_fc.lora_A: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_A.default: Linear
#   base_model.model.transformer.h.23.mlp.c_fc.lora_B: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_B.default: Linear
#   base_model.model.transformer.h.23.mlp.c_fc.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.23.mlp.c_fc.lora_magnitude_vector: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_dropout: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_dropout.default: Dropout
#   base_model.model.transformer.h.23.mlp.c_proj.lora_A: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_A.default: Linear
#   base_model.model.transformer.h.23.mlp.c_proj.lora_B: ModuleDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_B.default: Linear
#   base_model.model.transformer.h.23.mlp.c_proj.lora_embedding_A: ParameterDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_embedding_B: ParameterDict
#   base_model.model.transformer.h.23.mlp.c_proj.lora_magnitude_vector: ModuleDict
#
# Model moved to cuda

# %% [markdown]
# ## 4. Baseline Text Generation
#
# Before training, let's generate some text samples to establish a baseline for comparison.

# %%
# Function to generate text samples
def generate_text_samples(model, tokenizer, prompts, max_new_tokens=100, temperature=0.8, do_sample=True):
    model.eval()
    generated_texts = []

    with torch.no_grad():
        for prompt in prompts:
            # Tokenize prompt
            inputs = tokenizer(prompt, return_tensors="pt").to(device)

            # Generate
            with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=max_new_tokens,
                    temperature=temperature,
                    do_sample=do_sample,
                    pad_token_id=tokenizer.eos_token_id,
                    repetition_penalty=1.1,
                    top_p=0.9,
                )

            # Decode generated text
            generated = tokenizer.decode(outputs[0], skip_special_tokens=True)
            # Remove the prompt from the generated text
            generated_only = generated[len(prompt):].strip()
            generated_texts.append(generated_only)

    return generated_texts

# Test prompts for generation
test_prompts = [
    "The mysterious door at the end of the hallway",
    "In a world where dreams come true",
    "The last person on Earth heard a knock at the door"
]

print("Generating baseline samples...")
baseline_generations = generate_text_samples(lora_model, tokenizer, test_prompts)

print("\nBaseline Generations:")
print("=" * 60)
for i, (prompt, generated) in enumerate(zip(test_prompts, baseline_generations)):
    print(f"Prompt {i+1}: {prompt}")
    print(f"Generated: {generated[:200]}{'...' if len(generated) > 200 else ''}")
    print("-" * 60)
# Out:
# Generating baseline samples...
#
# Baseline Generations:
# ============================================================
# Prompt 1: The mysterious door at the end of the hallway
# Generated: , you can't open it without killing someone. So kill some people and return to this room with no one in sight (this will leave your character as a walking corpse) then turn around again... You'll be o...
# ------------------------------------------------------------
# Prompt 2: In a world where dreams come true
# Generated: , and we can take it from here. We have to be careful about what our plans are in the future."
# "I want you!" Ruby exclaimed with glee. "And if I didn't say so, then…you're going too! So much love for ...
# ------------------------------------------------------------
# Prompt 3: The last person on Earth heard a knock at the door
# Generated: . He turned to see his mother, who had entered through another room from which he could not hear her daughter's voice: "No! No!"
# But she was still there; with two of her best men and their dogs in tow...
# ------------------------------------------------------------

# %% [markdown]
# ## 5. Training Setup and Metrics
#
# For language generation tasks, we'll focus on perplexity as our primary metric, along with generation quality assessments.

# %%
# Custom metrics for language generation
def compute_perplexity(eval_preds):
    predictions, labels = eval_preds
    # Shift labels and predictions for causal LM
    shift_logits = predictions[..., :-1, :].contiguous()
    shift_labels = labels[..., 1:].contiguous()

    # Calculate loss
    loss_fct = nn.CrossEntropyLoss(ignore_index=-100)
    loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))

    # Calculate perplexity
    perplexity = torch.exp(loss)

    return {"perplexity": perplexity.item()}

# Training arguments optimized for generation
training_args = TrainingArguments(
    output_dir="./lora-gpt2-results",
    learning_rate=5e-4,  # Higher learning rate for LoRA
    per_device_train_batch_size=4,  # Smaller batch size for memory efficiency
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=4,  # Effective batch size of 16
    num_train_epochs=5,
    weight_decay=0.01,
    warmup_steps=100,
    eval_strategy="steps",  # Updated parameter name
    eval_steps=50,
    save_steps=50,
    logging_steps=25,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    fp16=torch.cuda.is_available(),
    dataloader_pin_memory=False,
    gradient_checkpointing=True,  # Memory optimization
    remove_unused_columns=False,
)

print("Training Configuration:")
print(f"Learning rate: {training_args.learning_rate}")
print(f"Batch size (per device): {training_args.per_device_train_batch_size}")
print(f"Gradient accumulation steps: {training_args.gradient_accumulation_steps}")
print(f"Effective batch size: {training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps}")
print(f"Epochs: {training_args.num_train_epochs}")
print(f"FP16: {training_args.fp16}")
print(f"Gradient checkpointing: {training_args.gradient_checkpointing}")
# Out:
# Training Configuration:
# Learning rate: 0.0005
# Batch size (per device): 4
# Gradient accumulation steps: 4
# Effective batch size: 16
# Epochs: 5
# FP16: True
# Gradient checkpointing: True

# %%
# Create trainer for language modeling
trainer = Trainer(
    model=lora_model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
)

# Set tokenizer reference for later use
trainer.tokenizer = tokenizer

# Evaluate baseline perplexity
print("Evaluating baseline perplexity...")
baseline_eval = trainer.evaluate()

print("\nBaseline Evaluation:")
print(f"Perplexity: {np.exp(baseline_eval['eval_loss']):.4f}")
print(f"Loss: {baseline_eval['eval_loss']:.4f}")

# Store baseline metrics
baseline_metrics = {
    'loss': baseline_eval['eval_loss'],
    'perplexity': np.exp(baseline_eval['eval_loss'])
}
# Out:
# Evaluating baseline perplexity...
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:00]
#     </div>
# Baseline Evaluation:
# Perplexity: 35.6303
# Loss: 3.5732

# %% [markdown]
# ## 6. LoRA Fine-Tuning Process
#
# Now we'll train the model with LoRA adapters specifically for our creative writing task.

# %%
# Start training
print("Starting LoRA fine-tuning for text generation...")
print("This may take several minutes depending on your hardware...")

start_time = time.time()

# Train the model
train_result = trainer.train()

training_time = time.time() - start_time
print(f"\nTraining completed in {training_time:.2f} seconds ({training_time/60:.2f} minutes)")

# Training statistics
print("\nTraining Statistics:")
print(f"Total training steps: {train_result.global_step}")
print(f"Final training loss: {train_result.training_loss:.4f}")
print(f"Training samples processed: {train_result.global_step * training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps}")
# Out:
# Starting LoRA fine-tuning for text generation...
# This may take several minutes depending on your hardware...
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 00:39, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed in 42.56 seconds (0.71 minutes)
#
# Training Statistics:
# Total training steps: 30
# Final training loss: 3.2138
# Training samples processed: 480

# %% [markdown]
# ## 7. Post-Training Evaluation
#
# Let's evaluate the fine-tuned model's performance.

# %%
# Post-training evaluation
print("Evaluating fine-tuned model...")
final_eval = trainer.evaluate()

print("\nFine-tuned Model Evaluation:")
print(f"Perplexity: {np.exp(final_eval['eval_loss']):.4f}")
print(f"Loss: {final_eval['eval_loss']:.4f}")

# Store final metrics
final_metrics = {
    'loss': final_eval['eval_loss'],
    'perplexity': np.exp(final_eval['eval_loss'])
}

# Calculate improvements
loss_improvement = baseline_metrics['loss'] - final_metrics['loss']
perplexity_improvement = baseline_metrics['perplexity'] - final_metrics['perplexity']
perplexity_improvement_pct = (perplexity_improvement / baseline_metrics['perplexity']) * 100

print("\nImprovements:")
print(f"Loss reduction: {loss_improvement:.4f}")
print(f"Perplexity reduction: {perplexity_improvement:.4f} ({perplexity_improvement_pct:.2f}%)")
# Out:
# Evaluating fine-tuned model...
#     <div>
#
#       <progress value='12' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:47]
#     </div>
# Fine-tuned Model Evaluation:
# Perplexity: 6.6556
# Loss: 1.8955
#
# Improvements:
# Loss reduction: 1.6777
# Perplexity reduction: 28.9747 (81.32%)

# %% [markdown]
# ## 8. Generation Quality Comparison
#
# The most important evaluation for generation models is the quality of the generated text. Let's compare before and after samples.

# %%
# Generate text with fine-tuned model
print("Generating samples with fine-tuned model...")
finetuned_generations = generate_text_samples(lora_model, tokenizer, test_prompts)

# Compare generations
print("\nGeneration Quality Comparison:")
print("=" * 80)

for i, prompt in enumerate(test_prompts):
    print(f"\nPrompt {i+1}: {prompt}")
    print("-" * 50)
    print(f"BASELINE: {baseline_generations[i][:150]}{'...' if len(baseline_generations[i]) > 150 else ''}")
    print(f"FINE-TUNED: {finetuned_generations[i][:150]}{'...' if len(finetuned_generations[i]) > 150 else ''}")
    print("=" * 80)
# Out:
# Generating samples with fine-tuned model...
#
# Generation Quality Comparison:
# ================================================================================
#
# Prompt 1: The mysterious door at the end of the hallway
# --------------------------------------------------
# BASELINE: , you can't open it without killing someone. So kill some people and return to this room with no one in sight (this will leave your character as a wal...
# FINE-TUNED: was a secret that only Sherlock could unlock. But if he opened it, someone else would walk through…
#  It took everything Sherlock knew to stop this dar...
# ================================================================================
#
# Prompt 2: In a world where dreams come true
# --------------------------------------------------
# BASELINE: , and we can take it from here. We have to be careful about what our plans are in the future."
# "I want you!" Ruby exclaimed with glee. "And if I didn'...
# FINE-TUNED: , the only way to know what really happened was to try.
# -A young girl discovers her parents are psychic ghosts who can see through people's memories, ...
# ================================================================================
#
# Prompt 3: The last person on Earth heard a knock at the door
# --------------------------------------------------
# BASELINE: . He turned to see his mother, who had entered through another room from which he could not hear her daughter's voice: "No! No!"
# But she was still the...
# FINE-TUNED: and realized it was coming from an alternate dimension. The only way to survive there would be for him or her, as well they might have forgotten every...
# ================================================================================

# %%
# Additional creative prompts to test specialization
creative_prompts = [
    "The magic in this world comes from",
    "She opened the ancient book and discovered",
    "The space station's AI began to",
    "In the underwater city, the inhabitants",
    "The time traveler's biggest mistake was"
]

print("Testing on specialized creative writing prompts...")
creative_generations = generate_text_samples(
    lora_model, tokenizer, creative_prompts,
    max_new_tokens=80, temperature=0.7
)

print("\nCreative Writing Generations:")
print("=" * 60)
for i, (prompt, generated) in enumerate(zip(creative_prompts, creative_generations)):
    print(f"{i+1}. {prompt} {generated}")
    print("-" * 60)
# Out:
# Testing on specialized creative writing prompts...
#
# Creative Writing Generations:
# ============================================================
# 1. The magic in this world comes from the shadows. Every spell is a lie, but one could find its way into someone's mind and turn them into an immortal creature. Only three people knew how to unlock these secrets, and only they would stop their greatest fears from becoming reality!
#  (C) Warner Bros
# ------------------------------------------------------------
# 2. She opened the ancient book and discovered it was filled with secrets about time travel. She realized she had been tricked by a sorcerer into thinking they were trapped in the past, but everything around her seemed to be changing forever. The city of Lusk was falling apart at an alarming rate—and every room contained something that could change reality itself!
#  (There were also strange things happening throughout history.) It wasn't long before someone broke through
# ------------------------------------------------------------
# 3. The space station's AI began to communicate with its inhabitants, and soon realized that the universe was being watched by an ancient conspiracy. With help from a mysterious benefactor named Isaac Clarke—who could see through time, weather storms of any color or shape —the scientists aboard the orbiting outpost were able "see" who they really wanted them for. But as their secrets grew ever more sinister...and beyond what anyone had imagined existed on Earth
# ------------------------------------------------------------
# 4. In the underwater city, the inhabitants were locked in a time loop that could only be stopped by finding the key to its secret. But when one of the residents died and all memories vanished, they discovered another dimension where everyone had mysteriously disappeared after waking up from a dream—and it was filled with people who'd never been there before!
# ------------------------------------------------------------
# 5. The time traveler's biggest mistake was underestimating his own abilities. The only way to stop him from killing everyone he touched, was by using the memories of every person in the world to rewrite history. But when that memory revealed an ancient secret hidden deep within Time itself…what would it mean for all of reality?
#  (Source: Dark Horse Comics)
# ------------------------------------------------------------

# %% [markdown]
# ## 9. Training History and Metrics Visualization
#
# Let's visualize how the model improved during training.

# %%
# Extract and visualize training history
log_history = trainer.state.log_history

# Separate training and evaluation logs
train_logs = [log for log in log_history if 'loss' in log and 'eval_loss' not in log]
eval_logs = [log for log in log_history if 'eval_loss' in log]

if train_logs and eval_logs:
    # Create training history visualization
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

    # Training loss
    train_steps = [log['step'] for log in train_logs]
    train_losses = [log['loss'] for log in train_logs]
    ax1.plot(train_steps, train_losses, 'b-', linewidth=2, label='Training Loss')
    ax1.set_title('Training Loss Over Time', fontweight='bold')
    ax1.set_xlabel('Steps')
    ax1.set_ylabel('Loss')
    ax1.grid(True, alpha=0.3)
    ax1.legend()

    # Validation loss
    eval_steps = [log['step'] for log in eval_logs]
    eval_losses = [log['eval_loss'] for log in eval_logs]
    ax2.plot(eval_steps, eval_losses, 'r-', linewidth=2, label='Validation Loss')
    ax2.set_title('Validation Loss Over Time', fontweight='bold')
    ax2.set_xlabel('Steps')
    ax2.set_ylabel('Loss')
    ax2.grid(True, alpha=0.3)
    ax2.legend()

    # Perplexity over time
    eval_perplexities = [np.exp(loss) for loss in eval_losses]
    ax3.plot(eval_steps, eval_perplexities, 'g-', linewidth=2, label='Perplexity')
    ax3.set_title('Validation Perplexity Over Time', fontweight='bold')
    ax3.set_xlabel('Steps')
    ax3.set_ylabel('Perplexity')
    ax3.grid(True, alpha=0.3)
    ax3.legend()

    # Learning rate
    if 'learning_rate' in train_logs[0]:
        learning_rates = [log['learning_rate'] for log in train_logs]
        ax4.plot(train_steps, learning_rates, 'purple', linewidth=2, label='Learning Rate')
        ax4.set_title('Learning Rate Schedule', fontweight='bold')
        ax4.set_xlabel('Steps')
        ax4.set_ylabel('Learning Rate')
        ax4.grid(True, alpha=0.3)
        ax4.legend()
    else:
        ax4.text(0.5, 0.5, 'Learning Rate\nData Not Available',
                transform=ax4.transAxes, ha='center', va='center',
                fontsize=12, fontweight='bold')
        ax4.set_title('Learning Rate Schedule', fontweight='bold')

    plt.tight_layout()
    plt.show()

    print(f"Training progressed over {len(train_logs)} steps")
    print(f"Best validation loss: {min(eval_losses):.4f}")
    print(f"Best validation perplexity: {min(eval_perplexities):.4f}")
    print(f"Final validation perplexity: {eval_perplexities[-1]:.4f}")
else:
    print("Training history not available for detailed plotting.")
# Out:
# Training progressed over 1 steps
# Best validation loss: 1.8955
# Best validation perplexity: 6.6556
# Final validation perplexity: 6.6556

# %% [markdown]
# ## 10. Model Efficiency Analysis
#
# Let's analyze the efficiency benefits of LoRA for decoder models.

# %%
# Efficiency analysis for decoder model
def analyze_decoder_efficiency(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    frozen_params = total_params - trainable_params

    # Analyze LoRA-specific parameters
    lora_params = 0
    base_model_params = 0

    for name, param in model.named_parameters():
        if 'lora' in name.lower():
            lora_params += param.numel()
        else:
            base_model_params += param.numel()

    return {
        'total': total_params,
        'trainable': trainable_params,
        'frozen': frozen_params,
        'lora_only': lora_params,
        'base_model': base_model_params,
        'trainable_percentage': (trainable_params / total_params) * 100,
        'lora_percentage': (lora_params / total_params) * 100
    }

# Analyze our LoRA decoder model
efficiency_stats = analyze_decoder_efficiency(lora_model)

print("LoRA Decoder Model Efficiency Analysis:")
print("=" * 60)
print(f"Base model (GPT-2 Medium): {MODEL_NAME}")
print(f"Total parameters: {efficiency_stats['total']:,}")
print(f"Base model parameters: {efficiency_stats['base_model']:,}")
print(f"LoRA parameters: {efficiency_stats['lora_only']:,}")
print(f"Trainable parameters: {efficiency_stats['trainable']:,}")
print(f"Frozen parameters: {efficiency_stats['frozen']:,}")
print(f"\nEfficiency Metrics:")
print(f"Trainable percentage: {efficiency_stats['trainable_percentage']:.3f}%")
print(f"LoRA-only percentage: {efficiency_stats['lora_percentage']:.3f}%")
print(f"Parameter reduction: {100 - efficiency_stats['trainable_percentage']:.3f}%")

# Storage and memory analysis
bytes_per_param = 2 if torch.cuda.is_available() else 4  # FP16 vs FP32
base_model_size_mb = (efficiency_stats['base_model'] * bytes_per_param) / (1024**2)
lora_adapter_size_mb = (efficiency_stats['lora_only'] * bytes_per_param) / (1024**2)
total_size_mb = (efficiency_stats['total'] * bytes_per_param) / (1024**2)

print(f"\nStorage Analysis:")
print(f"Base model size: {base_model_size_mb:.2f} MB")
print(f"LoRA adapter size: {lora_adapter_size_mb:.2f} MB")
print(f"Total model size: {total_size_mb:.2f} MB")
print(f"Adapter overhead: {(lora_adapter_size_mb/base_model_size_mb)*100:.2f}%")
# Out:
# LoRA Decoder Model Efficiency Analysis:
# ============================================================
# Base model (GPT-2 Medium): gpt2-medium
# Total parameters: 367,406,080
# Base model parameters: 354,823,168
# LoRA parameters: 12,582,912
# Trainable parameters: 12,582,912
# Frozen parameters: 354,823,168
#
# Efficiency Metrics:
# Trainable percentage: 3.425%
# LoRA-only percentage: 3.425%
# Parameter reduction: 96.575%
#
# Storage Analysis:
# Base model size: 676.77 MB
# LoRA adapter size: 24.00 MB
# Total model size: 700.77 MB
# Adapter overhead: 3.55%

# %%
# Visualization of decoder model efficiency
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# Parameter distribution pie chart
labels = ['Frozen Parameters', 'LoRA Parameters']
sizes = [efficiency_stats['frozen'], efficiency_stats['lora_only']]
colors = ['lightcoral', 'lightblue']
explode = (0, 0.1)

ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.3f%%',
        shadow=True, startangle=90)
ax1.set_title('Parameter Distribution\nin LoRA GPT-2 Model', fontweight='bold')

# Training efficiency comparison
categories = ['Full Fine-tuning', 'LoRA']
trainable_counts = [efficiency_stats['total'], efficiency_stats['trainable']]
colors_bar = ['red', 'blue']

bars = ax2.bar(categories, trainable_counts, color=colors_bar, alpha=0.7)
ax2.set_title('Trainable Parameters Comparison', fontweight='bold')
ax2.set_ylabel('Number of Parameters')
ax2.set_yscale('log')  # Log scale due to large difference
ax2.grid(True, alpha=0.3)

for bar, value in zip(bars, trainable_counts):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
             f'{value:,}', ha='center', va='bottom', fontweight='bold')

# Performance comparison
metrics = ['Baseline', 'Fine-tuned']
perplexities = [baseline_metrics['perplexity'], final_metrics['perplexity']]
losses = [baseline_metrics['loss'], final_metrics['loss']]

ax3.bar(metrics, perplexities, color=['orange', 'green'], alpha=0.7)
ax3.set_title('Perplexity Comparison', fontweight='bold')
ax3.set_ylabel('Perplexity')
ax3.grid(True, alpha=0.3)

for i, v in enumerate(perplexities):
    ax3.text(i, v, f'{v:.2f}', ha='center', va='bottom', fontweight='bold')

# Storage efficiency
storage_categories = ['Base Model', 'LoRA Adapter']
storage_sizes = [base_model_size_mb, lora_adapter_size_mb]

bars = ax4.bar(storage_categories, storage_sizes, color=['purple', 'cyan'], alpha=0.7)
ax4.set_title('Storage Requirements (MB)', fontweight='bold')
ax4.set_ylabel('Size (MB)')
ax4.grid(True, alpha=0.3)

for bar, value in zip(bars, storage_sizes):
    height = bar.get_height()
    ax4.text(bar.get_x() + bar.get_width()/2., height,
             f'{value:.1f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Advanced Generation Testing
#
# Let's test various generation parameters to see how our fine-tuned model performs across different settings.

# %%
# Test different generation parameters
def test_generation_parameters(model, tokenizer, prompt, device):
    """Test different generation settings"""
    test_configs = [
        {'temperature': 0.3, 'top_p': 0.9, 'name': 'Conservative'},
        {'temperature': 0.7, 'top_p': 0.9, 'name': 'Balanced'},
        {'temperature': 1.0, 'top_p': 0.8, 'name': 'Creative'},
        {'temperature': 1.2, 'top_p': 0.7, 'name': 'Highly Creative'}
    ]

    model.eval()
    results = []

    with torch.no_grad():
        inputs = tokenizer(prompt, return_tensors="pt").to(device)

        for config in test_configs:
            outputs = model.generate(
                **inputs,
                max_new_tokens=100,
                temperature=config['temperature'],
                top_p=config['top_p'],
                do_sample=True,
                pad_token_id=tokenizer.eos_token_id,
                repetition_penalty=1.1,
                num_return_sequences=1
            )

            generated = tokenizer.decode(outputs[0], skip_special_tokens=True)
            generated_only = generated[len(prompt):].strip()

            results.append({
                'config': config['name'],
                'text': generated_only
            })

    return results

# Test prompt
test_prompt = "The old wizard's tower stood abandoned for centuries, until one day"

print("Testing different generation parameters...")
generation_tests = test_generation_parameters(lora_model, tokenizer, test_prompt, device)

print(f"\nGeneration Parameter Testing:")
print(f"Prompt: {test_prompt}")
print("=" * 70)

for result in generation_tests:
    print(f"\n{result['config']} Setting:")
    print(f"{result['text'][:200]}{'...' if len(result['text']) > 200 else ''}")
    print("-" * 50)
# Out:
# Testing different generation parameters...
#
# Generation Parameter Testing:
# Prompt: The old wizard's tower stood abandoned for centuries, until one day
# ======================================================================
#
# Conservative Setting:
# a young girl came to visit. She was the only person in all of Equestria who could see into the past, and she had an ancient prophecy that would change everything. But what if her true power wasn't mag...
# --------------------------------------------------
#
# Balanced Setting:
# , a visitor showed up. It was revealed to be haunted by the ghosts of its former inhabitants... but who were they really? And what secrets did their actions hold?
# --------------------------------------------------
#
# Creative Setting:
# it was discovered by a curious young boy who could read minds. Using his prodigious gift to manipulate reality around him—and steal the memories of those closest and most vulnerable in his castle —the...
# --------------------------------------------------
#
# Highly Creative Setting:
# someone stumbled across a map hidden deep beneath the floor. Only those who could read it knew how to open its mysteries, but no one had ever discovered what secrets lay within...
# --------------------------------------------------

# %% [markdown]
# ## 12. Comprehensive Summary and Analysis
#
# Let's create a comprehensive summary of our LoRA decoder model fine-tuning experiment.

# %%
# Create comprehensive summary
def calculate_text_diversity(texts):
    """Calculate basic diversity metrics for generated texts"""
    all_words = []
    for text in texts:
        words = text.lower().split()
        all_words.extend(words)

    if not all_words:
        return 0, 0

    unique_words = len(set(all_words))
    total_words = len(all_words)
    diversity_ratio = unique_words / total_words if total_words > 0 else 0
    avg_length = np.mean([len(text.split()) for text in texts])

    return diversity_ratio, avg_length

# Analyze generation quality
baseline_diversity, baseline_avg_len = calculate_text_diversity(baseline_generations)
finetuned_diversity, finetuned_avg_len = calculate_text_diversity(finetuned_generations)

# Create summary statistics
summary_stats = {
    'Model Configuration': {
        'Base Model': MODEL_NAME,
        'Model Size': f"{sum(p.numel() for p in model.parameters()):,} parameters",
        'LoRA Rank': lora_config.r,
        'LoRA Alpha': lora_config.lora_alpha,
        'Target Modules': ', '.join(lora_config.target_modules)
    },
    'Training Metrics': {
        'Training Time': f"{training_time/60:.2f} minutes",
        'Training Steps': train_result.global_step,
        'Final Training Loss': f"{train_result.training_loss:.4f}",
        'Learning Rate': training_args.learning_rate,
        'Batch Size': training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps
    },
    'Performance Improvements': {
        'Baseline Perplexity': f"{baseline_metrics['perplexity']:.4f}",
        'Final Perplexity': f"{final_metrics['perplexity']:.4f}",
        'Perplexity Reduction': f"{perplexity_improvement:.4f} ({perplexity_improvement_pct:.2f}%)",
        'Loss Reduction': f"{loss_improvement:.4f}"
    },
    'Efficiency Metrics': {
        'Total Parameters': f"{efficiency_stats['total']:,}",
        'Trainable Parameters': f"{efficiency_stats['trainable']:,}",
        'LoRA Parameters': f"{efficiency_stats['lora_only']:,}",
        'Parameter Efficiency': f"{100 - efficiency_stats['trainable_percentage']:.3f}% reduction",
        'Storage Efficiency': f"{lora_adapter_size_mb:.2f} MB (adapter only)"
    },
    'Generation Quality': {
        'Baseline Diversity': f"{baseline_diversity:.3f}",
        'Fine-tuned Diversity': f"{finetuned_diversity:.3f}",
        'Baseline Avg Length': f"{baseline_avg_len:.1f} words",
        'Fine-tuned Avg Length': f"{finetuned_avg_len:.1f} words"
    }
}

print("\n" + "=" * 70)
print("LORA DECODER MODEL FINE-TUNING COMPREHENSIVE SUMMARY")
print("=" * 70)

for category, metrics in summary_stats.items():
    print(f"\n{category}:")
    print("-" * len(category))
    for key, value in metrics.items():
        print(f"  {key}: {value}")

print("\n" + "=" * 70)
print("KEY INSIGHTS FOR DECODER MODELS:")
print("=" * 70)
insights = [
    "• LoRA effectively adapts decoder models with minimal parameters",
    "• Generation quality improves while maintaining efficiency",
    "• Targeting attention and MLP layers provides good coverage",
    "• Higher rank (32 vs 16) benefits generation tasks",
    "• Perplexity reduction indicates better language modeling",
    "• Creative writing specialization achieved with domain data",
    "• Memory efficiency enables fine-tuning large models locally",
    "• Multiple adapters can be trained for different writing styles"
]

for insight in insights:
    print(insight)

print("\n" + "=" * 70)
print("DECODER MODEL SPECIFIC CONSIDERATIONS:")
print("=" * 70)
considerations = [
    "• Causal attention masks require different LoRA placement strategies",
    "• Generation metrics (perplexity, coherence) matter more than accuracy",
    "• Temperature and sampling parameters significantly affect output",
    "• Longer sequences may require gradient checkpointing for memory",
    "• Repetition penalty helps maintain generation quality",
    "• Domain-specific fine-tuning creates specialized generators"
]

for consideration in considerations:
    print(consideration)
# Out:
# ======================================================================
# LORA DECODER MODEL FINE-TUNING COMPREHENSIVE SUMMARY
# ======================================================================
#
# Model Configuration:
# -------------------
#   Base Model: gpt2-medium
#   Model Size: 367,406,080 parameters
#   LoRA Rank: 32
#   LoRA Alpha: 64
#   Target Modules: c_fc, c_proj, c_attn
#
# Training Metrics:
# ----------------
#   Training Time: 0.71 minutes
#   Training Steps: 30
#   Final Training Loss: 3.2138
#   Learning Rate: 0.0005
#   Batch Size: 16
#
# Performance Improvements:
# ------------------------
#   Baseline Perplexity: 35.6303
#   Final Perplexity: 6.6556
#   Perplexity Reduction: 28.9747 (81.32%)
#   Loss Reduction: 1.6777
#
# Efficiency Metrics:
# ------------------
#   Total Parameters: 367,406,080
#   Trainable Parameters: 12,582,912
#   LoRA Parameters: 12,582,912
#   Parameter Efficiency: 96.575% reduction
#   Storage Efficiency: 24.00 MB (adapter only)
#
# Generation Quality:
# ------------------
#   Baseline Diversity: 0.760
#   Fine-tuned Diversity: 0.754
#   Baseline Avg Length: 83.3 words
#   Fine-tuned Avg Length: 62.3 words
#
# ======================================================================
# KEY INSIGHTS FOR DECODER MODELS:
# ======================================================================
# • LoRA effectively adapts decoder models with minimal parameters
# • Generation quality improves while maintaining efficiency
# • Targeting attention and MLP layers provides good coverage
# • Higher rank (32 vs 16) benefits generation tasks
# • Perplexity reduction indicates better language modeling
# • Creative writing specialization achieved with domain data
# • Memory efficiency enables fine-tuning large models locally
# • Multiple adapters can be trained for different writing styles
#
# ======================================================================
# DECODER MODEL SPECIFIC CONSIDERATIONS:
# ======================================================================
# • Causal attention masks require different LoRA placement strategies
# • Generation metrics (perplexity, coherence) matter more than accuracy
# • Temperature and sampling parameters significantly affect output
# • Longer sequences may require gradient checkpointing for memory
# • Repetition penalty helps maintain generation quality
# • Domain-specific fine-tuning creates specialized generators

# %%
# Save comprehensive results
# Save comprehensive results
comprehensive_results = {
    'experiment_type': 'LoRA Decoder Model Fine-tuning',
    'model_info': {
        'base_model': MODEL_NAME,
        'total_parameters': int(efficiency_stats['total']),
        'model_type': 'decoder_only'
    },
    'lora_config': {
        'task_type': str(lora_config.task_type),
        'r': int(lora_config.r),
        'alpha': int(lora_config.lora_alpha),
        'dropout': float(lora_config.lora_dropout),
        'target_modules': list(lora_config.target_modules) if isinstance(lora_config.target_modules, set) else lora_config.target_modules
    },
    'training_results': {
        'training_time_minutes': float(training_time / 60),
        'total_steps': int(train_result.global_step),
        'final_training_loss': float(train_result.training_loss),
        'baseline_metrics': {
            'loss': float(baseline_metrics['loss']),
            'perplexity': float(baseline_metrics['perplexity'])
        },
        'final_metrics': {
            'loss': float(final_metrics['loss']),
            'perplexity': float(final_metrics['perplexity'])
        },
        'improvements': {
            'loss_reduction': float(loss_improvement),
            'perplexity_reduction': float(perplexity_improvement),
            'perplexity_reduction_percent': float(perplexity_improvement_pct)
        }
    },
    'efficiency_analysis': {
        'total': int(efficiency_stats['total']),
        'trainable': int(efficiency_stats['trainable']),
        'frozen': int(efficiency_stats['frozen']),
        'lora_only': int(efficiency_stats['lora_only']),
        'base_model': int(efficiency_stats['base_model']),
        'trainable_percentage': float(efficiency_stats['trainable_percentage']),
        'lora_percentage': float(efficiency_stats['lora_percentage'])
    },
    'generation_samples': {
        'test_prompts': test_prompts,
        'baseline_generations': baseline_generations,
        'finetuned_generations': finetuned_generations,
        'creative_prompts': creative_prompts,
        'creative_generations': creative_generations
    },
    'quality_metrics': {
        'baseline_diversity': float(baseline_diversity),
        'finetuned_diversity': float(finetuned_diversity),
        'baseline_avg_length': float(baseline_avg_len),
        'finetuned_avg_length': float(finetuned_avg_len)
    }
}


# Save results to JSON
with open('lora_decoder_experiment_results.json', 'w') as f:
    json.dump(comprehensive_results, f, indent=2)

print("\nComprehensive results saved to 'lora_decoder_experiment_results.json'")
print("\nLoRA Decoder Model Fine-tuning Experiment Completed Successfully! 🎉")

# Final generation showcase
print("\n" + "=" * 70)
print("FINAL GENERATION SHOWCASE")
print("=" * 70)

showcase_prompt = "In a world where memories can be extracted and traded"
showcase_generation = generate_text_samples(
    lora_model, tokenizer, [showcase_prompt],
    max_new_tokens=120, temperature=0.8
)

print(f"Prompt: {showcase_prompt}")
print(f"Generated Story: {showcase_generation[0]}")
print("=" * 70)
# Out:
# Comprehensive results saved to 'lora_decoder_experiment_results.json'
#
# LoRA Decoder Model Fine-tuning Experiment Completed Successfully! 🎉
#
# ======================================================================
# FINAL GENERATION SHOWCASE
# ======================================================================
# Prompt: In a world where memories can be extracted and traded
# Generated Story: for anything from food to love, the only thing that kept secrets safe was memory itself. But when an ancient artifact began keeping its owner's past locked away, everyone realized it could change everything…
#  (c) Marvel Entertainment
# ======================================================================
